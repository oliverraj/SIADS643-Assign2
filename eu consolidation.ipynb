# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt 
import seaborn as sns
import re

# %%
data_EU_moderna = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Moderna' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_moderna = pd.concat([data_EU_moderna, x], axis = 0, ignore_index = True)
    print(file_name)
data_EU_moderna.head(2)
# Out:
# EU Files\EU Moderna 1 2021.csv
# EU Files\EU Moderna 1 2022.csv
# EU Files\EU Moderna 1 2023.csv
# EU Files\EU Moderna 2 2023.csv
# EU Files\EU Moderna 3 2022.csv
# EU Files\EU Moderna 3 2023.csv
# EU Files\EU Moderna 4 2022.csv
# EU Files\EU Moderna 4 2023.csv
#      EU Local Number  Report Type EV Gateway Receipt Date  \
# 0  EU-EC-10011128459  Spontaneous     2021-12-31 00:00:00
# 1  EU-EC-10011128525  Spontaneous     2021-12-31 00:00:00
#
#   Primary Source Qualification Primary Source Country for Regulatory Purposes  \
# 0  Non Healthcare Professional                     Non European Economic Area
# 1  Non Healthcare Professional                         European Economic Area
#
#   Literature Reference Patient Age Group Patient Age Group (as per reporter)  \
# 0        Not available       18-64 Years                       Not Specified
# 1        Not available       18-64 Years                               Adult
#
#   Parent Child Report Patient Sex  \
# 0                  No      Female
# 1                  No      Female
#
#   Reaction List PT (Duration – Outcome - Seriousness Criteria)  \
# 0  Eye pain (n/a - Not Recovered/Not Resolved - O...
# 1  Chest pain (n/a - Unknown - ),<BR><BR>Dizzines...
#
#   Suspect/interacting Drug List (Drug Char - Indication PT - Action taken - [Duration - Dose - Route])  \
# 0  SPIKEVAX [COVID-19 MRNA VACCINE MODERNA (CX-02...
# 1  SPIKEVAX [COVID-19 MRNA VACCINE MODERNA (CX-02...
#
#   Concomitant/Not Administered Drug List (Drug Char - Indication PT - Action taken - [Duration - Dose - Route])  \
# 0  COVID-19 VACCINE ASTRAZENECA (CHADOX1 NCOV-19)...
# 1                                       Not reported
#
#                                            ICSR Form
# 0  <a target="_blank" href="https://dap.ema.europ...
# 1  <a target="_blank" href="https://dap.ema.europ...

# %%
data_EU_moderna.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_moderna = data_EU_moderna[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
data_EU_moderna.head(2)
# Out:
#                EU_ID    AGE_GROUP     SEX  \
# 0  EU-EC-10011128459  18-64 Years  Female
# 1  EU-EC-10011128525  18-64 Years  Female
#
#                                        SYMPTOMS_LIST
# 0  Eye pain (n/a - Not Recovered/Not Resolved - O...
# 1  Chest pain (n/a - Unknown - ),<BR><BR>Dizzines...

# %%
def extract_symptoms(symptom_list):
    if isinstance(symptom_list, str):
        # Split the reactions using the HTML break tag as the delimiter
        symptoms = re.split(r'<BR><BR>', symptom_list)
        # Further clean and extract just the reaction name before the first parenthesis
        symptoms = [re.split(r'\(', symptom.strip())[0].strip() for symptom in symptoms]
        return symptoms
    else:
        return []

# %%
data_EU_moderna["SYMPTOMS_LIST"] = data_EU_moderna["SYMPTOMS_LIST"].apply(extract_symptoms)
data_EU_moderna
# Out:
#                     EU_ID      AGE_GROUP     SEX  \
# 0       EU-EC-10011128459    18-64 Years  Female
# 1       EU-EC-10011128525    18-64 Years  Female
# 2       EU-EC-10011128535    18-64 Years    Male
# 3       EU-EC-10011128589    65-85 Years  Female
# 4       EU-EC-10011128599  Not Specified  Female
# ...                   ...            ...     ...
# 393819  EU-EC-10014357459    65-85 Years    Male
# 393820  EU-EC-10014357555  Not Specified    Male
# 393821  EU-EC-10014349445  Not Specified    Male
# 393822  EU-EC-10014351587  Not Specified    Male
# 393823  EU-EC-10014352537  Not Specified    Male
#
#                                             SYMPTOMS_LIST
# 0                          [Eye pain, Migraine, Vomiting]
# 1       [Chest pain, Dizziness, Fatigue, Headache, Mya...
# 2       [Bundle branch block right, C-reactive protein...
# 3        [COVID-19, Flank pain, SARS-CoV-2 test positive]
# 4           [Ear pain, Nausea, Pain, Pyrexia, Tenderness]
# ...                                                   ...
# 393819  [Atrial fibrillation, Cardiac failure congesti...
# 393820  [COVID-19, COVID-19 immunisation, Interchange ...
# 393821                                            [Death]
# 393822                                            [Death]
# 393823                                            [Death]
#
# [393824 rows x 4 columns]

# %%
data_EU_moderna["AGE_GROUP"] = data_EU_moderna["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
data_EU_moderna
# Out:
#                     EU_ID      AGE_GROUP     SEX  \
# 0       EU-EC-10011128459          18-64  Female
# 1       EU-EC-10011128525          18-64  Female
# 2       EU-EC-10011128535          18-64    Male
# 3       EU-EC-10011128589          65-85  Female
# 4       EU-EC-10011128599  Not Specified  Female
# ...                   ...            ...     ...
# 393819  EU-EC-10014357459          65-85    Male
# 393820  EU-EC-10014357555  Not Specified    Male
# 393821  EU-EC-10014349445  Not Specified    Male
# 393822  EU-EC-10014351587  Not Specified    Male
# 393823  EU-EC-10014352537  Not Specified    Male
#
#                                             SYMPTOMS_LIST
# 0                          [Eye pain, Migraine, Vomiting]
# 1       [Chest pain, Dizziness, Fatigue, Headache, Mya...
# 2       [Bundle branch block right, C-reactive protein...
# 3        [COVID-19, Flank pain, SARS-CoV-2 test positive]
# 4           [Ear pain, Nausea, Pain, Pyrexia, Tenderness]
# ...                                                   ...
# 393819  [Atrial fibrillation, Cardiac failure congesti...
# 393820  [COVID-19, COVID-19 immunisation, Interchange ...
# 393821                                            [Death]
# 393822                                            [Death]
# 393823                                            [Death]
#
# [393824 rows x 4 columns]

# %%
data_EU_moderna["SEX"] = data_EU_moderna["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_moderna["SEX"] = data_EU_moderna["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_moderna["SEX"] = data_EU_moderna["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
data_EU_moderna
# Out:
#                     EU_ID      AGE_GROUP SEX  \
# 0       EU-EC-10011128459          18-64   F
# 1       EU-EC-10011128525          18-64   F
# 2       EU-EC-10011128535          18-64   M
# 3       EU-EC-10011128589          65-85   F
# 4       EU-EC-10011128599  Not Specified   F
# ...                   ...            ...  ..
# 393819  EU-EC-10014357459          65-85   M
# 393820  EU-EC-10014357555  Not Specified   M
# 393821  EU-EC-10014349445  Not Specified   M
# 393822  EU-EC-10014351587  Not Specified   M
# 393823  EU-EC-10014352537  Not Specified   M
#
#                                             SYMPTOMS_LIST
# 0                          [Eye pain, Migraine, Vomiting]
# 1       [Chest pain, Dizziness, Fatigue, Headache, Mya...
# 2       [Bundle branch block right, C-reactive protein...
# 3        [COVID-19, Flank pain, SARS-CoV-2 test positive]
# 4           [Ear pain, Nausea, Pain, Pyrexia, Tenderness]
# ...                                                   ...
# 393819  [Atrial fibrillation, Cardiac failure congesti...
# 393820  [COVID-19, COVID-19 immunisation, Interchange ...
# 393821                                            [Death]
# 393822                                            [Death]
# 393823                                            [Death]
#
# [393824 rows x 4 columns]

# %%
data_EU_moderna["SEX"].unique()
# Out:
# array(['F', 'M', 'U'], dtype=object)

# %%
# ",".join(data_EU_moderna["Symptoms List"][0]).split(",")
data_EU_moderna["SYMPTOMS_LIST"][0]
# Out:
# ['Eye pain', 'Migraine', 'Vomiting']

# %%
symptom_columns = ["SYMPTOM1", "SYMPTOM2", "SYMPTOM3", "SYMPTOM4", "SYMPTOM5"]

# %%
# symptom_df = data_EU_moderna["Symptoms List"].str.split(",", expand=True)
# symptom_df.columns = symptom_df
# x = pd.concat([data_EU_moderna, symptom_df], axis=1)
# x

# %%
# pd.DataFrame(data_EU_moderna["Symptoms List"].to_list(), columns = ["SYMPTOM1", "SYMPTOM2", "SYMPTOM3", "SYMPTOM4", "SYMPTOM5"])

# %%
data_EU_moderna['VAX_MANU'] = "MODERNA"
data_EU_moderna
# Out:
#                     EU_ID      AGE_GROUP SEX  \
# 0       EU-EC-10011128459          18-64   F
# 1       EU-EC-10011128525          18-64   F
# 2       EU-EC-10011128535          18-64   M
# 3       EU-EC-10011128589          65-85   F
# 4       EU-EC-10011128599  Not Specified   F
# ...                   ...            ...  ..
# 393819  EU-EC-10014357459          65-85   M
# 393820  EU-EC-10014357555  Not Specified   M
# 393821  EU-EC-10014349445  Not Specified   M
# 393822  EU-EC-10014351587  Not Specified   M
# 393823  EU-EC-10014352537  Not Specified   M
#
#                                             SYMPTOMS_LIST VAX_MANU
# 0                          [Eye pain, Migraine, Vomiting]  MODERNA
# 1       [Chest pain, Dizziness, Fatigue, Headache, Mya...  MODERNA
# 2       [Bundle branch block right, C-reactive protein...  MODERNA
# 3        [COVID-19, Flank pain, SARS-CoV-2 test positive]  MODERNA
# 4           [Ear pain, Nausea, Pain, Pyrexia, Tenderness]  MODERNA
# ...                                                   ...      ...
# 393819  [Atrial fibrillation, Cardiac failure congesti...  MODERNA
# 393820  [COVID-19, COVID-19 immunisation, Interchange ...  MODERNA
# 393821                                            [Death]  MODERNA
# 393822                                            [Death]  MODERNA
# 393823                                            [Death]  MODERNA
#
# [393824 rows x 5 columns]

# %%
x = data_EU_moderna.explode(["SYMPTOMS_LIST"])
x
# Out:
#                     EU_ID      AGE_GROUP SEX                    SYMPTOMS_LIST  \
# 0       EU-EC-10011128459          18-64   F                         Eye pain
# 0       EU-EC-10011128459          18-64   F                         Migraine
# 0       EU-EC-10011128459          18-64   F                         Vomiting
# 1       EU-EC-10011128525          18-64   F                       Chest pain
# 1       EU-EC-10011128525          18-64   F                        Dizziness
# ...                   ...            ...  ..                              ...
# 393820  EU-EC-10014357555  Not Specified   M            COVID-19 immunisation
# 393820  EU-EC-10014357555  Not Specified   M  Interchange of vaccine products
# 393821  EU-EC-10014349445  Not Specified   M                            Death
# 393822  EU-EC-10014351587  Not Specified   M                            Death
# 393823  EU-EC-10014352537  Not Specified   M                            Death
#
#        VAX_MANU
# 0       MODERNA
# 0       MODERNA
# 0       MODERNA
# 1       MODERNA
# 1       MODERNA
# ...         ...
# 393820  MODERNA
# 393820  MODERNA
# 393821  MODERNA
# 393822  MODERNA
# 393823  MODERNA
#
# [1563055 rows x 5 columns]

# %%
x["SYMPTOMS_LIST"].value_counts().head(20)
# Out:
# SYMPTOMS_LIST
# Headache                   93583
# Pyrexia                    89640
# Fatigue                    79991
# Myalgia                    63877
# Chills                     61459
# Malaise                    51228
# Nausea                     46470
# Injection site pain        40115
# Arthralgia                 39163
# Dizziness                  27891
# Pain in extremity          24153
# Vaccination site pain      22165
# Lymphadenopathy            21368
# Dyspnoea                   18660
# Pain                       18479
# Injection site erythema    17769
# Injection site swelling    17464
# COVID-19                   16496
# Asthenia                   15119
# Vomiting                   14050
# Name: count, dtype: int64

# %%
data_EU_pfizer = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Pfizer' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_pfizer = pd.concat([data_EU_pfizer, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_pfizer.head(2)
data_EU_pfizer.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_pfizer = data_EU_pfizer[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_pfizer.head(2)
data_EU_pfizer["SYMPTOMS_LIST"] = data_EU_pfizer["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_pfizer
data_EU_pfizer["AGE_GROUP"] = data_EU_pfizer["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_pfizer
data_EU_pfizer["SEX"] = data_EU_pfizer["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_pfizer["SEX"] = data_EU_pfizer["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_pfizer["SEX"] = data_EU_pfizer["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_pfizer
data_EU_pfizer['VAX_MANU'] = "PFIZER"
data_EU_pfizer
# Out:
# EU Files\EU Pfizer 1 2021.csv
# EU Files\EU Pfizer 1 2022.csv
# EU Files\EU Pfizer 1 2023.csv
# EU Files\EU Pfizer 2 2023.csv
# EU Files\EU Pfizer 3 2022.csv
# EU Files\EU Pfizer 3 2023.csv
# EU Files\EU Pfizer 4 2022.csv
# EU Files\EU Pfizer 4 2023.csv
#                     EU_ID AGE_GROUP SEX  \
# 0       EU-EC-10011128486     18-64   M
# 1       EU-EC-10011128558     65-85   F
# 2       EU-EC-10011128590     18-64   M
# 3       EU-EC-10011128595     18-64   M
# 4       EU-EC-10011128635     65-85   F
# ...                   ...       ...  ..
# 602907  EU-EC-10014349651     65-85   M
# 602908  EU-EC-10014349759     18-64   F
# 602909  EU-EC-10014350772     65-85   F
# 602910  EU-EC-10014351070     18-64   M
# 602911  EU-EC-10014351390     18-64   F
#
#                                             SYMPTOMS_LIST VAX_MANU
# 0                                       [Alopecia areata]   PFIZER
# 1                                             [Neuralgia]   PFIZER
# 2       [Myocardial infarction, Resuscitation, Ventric...   PFIZER
# 3                                   [Vaccination failure]   PFIZER
# 4       [Arthralgia, Confusional state, Disturbance in...   PFIZER
# ...                                                   ...      ...
# 602907  [Herpes zoster, Ophthalmic herpes zoster, Prur...   PFIZER
# 602908                       [COVID-19, Drug ineffective]   PFIZER
# 602909                   [Atrial fibrillation, Diarrhoea]   PFIZER
# 602910  [Disturbance in attention, Impaired quality of...   PFIZER
# 602911  [Chest pain, Dizziness, Dyspnoea, Fatigue, Hea...   PFIZER
#
# [602912 rows x 5 columns]

# %%
data_EU_astrazeneca = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Astrazeneca' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_astrazeneca = pd.concat([data_EU_astrazeneca, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_astrazeneca.head(2)
data_EU_astrazeneca.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_astrazeneca = data_EU_astrazeneca[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_astrazeneca.head(2)
data_EU_astrazeneca["SYMPTOMS_LIST"] = data_EU_astrazeneca["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_astrazeneca
data_EU_astrazeneca["AGE_GROUP"] = data_EU_astrazeneca["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_astrazeneca
data_EU_astrazeneca["SEX"] = data_EU_astrazeneca["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_astrazeneca["SEX"] = data_EU_astrazeneca["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_astrazeneca["SEX"] = data_EU_astrazeneca["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_astrazeneca
data_EU_astrazeneca['VAX_MANU'] = "ASTRAZENECA"
data_EU_astrazeneca
# Out:
# EU Files\EU Astrazeneca 1 2021.csv
# EU Files\EU Astrazeneca 1 2022.csv
# EU Files\EU Astrazeneca 1 2023.csv
#                     EU_ID      AGE_GROUP SEX  \
# 0       EU-EC-10011128636          18-64   M
# 1       EU-EC-10011128637          65-85   F
# 2       EU-EC-10011128695          18-64   M
# 3       EU-EC-10011128705          65-85   F
# 4       EU-EC-10011128724          65-85   M
# ...                   ...            ...  ..
# 427815  EU-EC-10014351569  Not Specified   M
# 427816  EU-EC-10014351631          65-85   M
# 427817  EU-EC-10014352064   More than 85   F
# 427818  EU-EC-10014352150          18-64   F
# 427819  EU-EC-10014352190          65-85   M
#
#                                             SYMPTOMS_LIST     VAX_MANU
# 0       [Dysaesthesia, Muscle contractions involuntary...  ASTRAZENECA
# 1       [Abdominal pain upper, Blood pressure increase...  ASTRAZENECA
# 2                                              [Tinnitus]  ASTRAZENECA
# 3                                             [Urticaria]  ASTRAZENECA
# 4                                       [Cardiac failure]  ASTRAZENECA
# ...                                                   ...          ...
# 427815  [Arthralgia, Chills, Colitis, Colitis ulcerati...  ASTRAZENECA
# 427816  [Cardiovascular disorder, Interchange of vacci...  ASTRAZENECA
# 427817  [Glaucoma, Macular degeneration, Neck pain, Ox...  ASTRAZENECA
# 427818  [Abdominal pain, Alopecia, Asthenia, Decreased...  ASTRAZENECA
# 427819                         [Cerebrovascular accident]  ASTRAZENECA
#
# [427820 rows x 5 columns]

# %%
data_EU_janssen = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Janssen' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_janssen = pd.concat([data_EU_janssen, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_janssen.head(2)
data_EU_janssen.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_janssen = data_EU_janssen[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_janssen.head(2)
data_EU_janssen["SYMPTOMS_LIST"] = data_EU_janssen["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_janssen
data_EU_janssen["AGE_GROUP"] = data_EU_janssen["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_janssen
data_EU_janssen["SEX"] = data_EU_janssen["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_janssen["SEX"] = data_EU_janssen["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_janssen["SEX"] = data_EU_janssen["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_janssen
data_EU_janssen['VAX_MANU'] = "JANSSEN"
data_EU_janssen
# Out:
# EU Files\EU Janssen 1 2021.csv
# EU Files\EU Janssen 1 2022.csv
# EU Files\EU Janssen 1 2023.csv
#                    EU_ID      AGE_GROUP SEX  \
# 0      EU-EC-10011128588  Not Specified   M
# 1      EU-EC-10011128704          18-64   M
# 2      EU-EC-10011129053          18-64   M
# 3      EU-EC-10011129123          18-64   F
# 4      EU-EC-10011129244          18-64   M
# ...                  ...            ...  ..
# 71560  EU-EC-10014347423  Not Specified   M
# 71561  EU-EC-10014347424          18-64   M
# 71562  EU-EC-10014347425          18-64   F
# 71563  EU-EC-10014347426          18-64   M
# 71564  EU-EC-10014347456          18-64   F
#
#                                            SYMPTOMS_LIST VAX_MANU
# 0                                  [Vaccination failure]  JANSSEN
# 1                           [Asthenia, Myalgia, Vertigo]  JANSSEN
# 2                       [Arthralgia, Bone marrow oedema]  JANSSEN
# 3                            [Hypertension, Tachycardia]  JANSSEN
# 4                        [COVID-19, Vaccination failure]  JANSSEN
# ...                                                  ...      ...
# 71560  [Back pain, Dizziness, Pain in extremity, Pyre...  JANSSEN
# 71561                               [Arthritis, Pyrexia]  JANSSEN
# 71562  [Asthenia, Impaired work ability, Pyrexia, Vac...  JANSSEN
# 71563                    [Arthralgia, Headache, Pyrexia]  JANSSEN
# 71564                                 [Productive cough]  JANSSEN
#
# [71565 rows x 5 columns]

# %%
data_EU_novavax = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Novavax' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_novavax = pd.concat([data_EU_novavax, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_novavax.head(2)
data_EU_novavax.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_novavax = data_EU_novavax[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_novavax.head(2)
data_EU_novavax["SYMPTOMS_LIST"] = data_EU_novavax["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_novavax
data_EU_novavax["AGE_GROUP"] = data_EU_novavax["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_novavax
data_EU_novavax["SEX"] = data_EU_novavax["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_novavax["SEX"] = data_EU_novavax["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_novavax["SEX"] = data_EU_novavax["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_novavax
data_EU_novavax['VAX_MANU'] = "NOVAVAX"
data_EU_novavax
# Out:
# EU Files\EU Novavax 1 2022.csv
# EU Files\EU Novavax 1 2023.csv
# EU Files\EU Novavax 2 2023.csv
#                   EU_ID AGE_GROUP SEX  \
# 0     EU-EC-10014341832     65-85   M
# 1     EU-EC-10014334441     18-64   F
# 2     EU-EC-10014335705     18-64   M
# 3     EU-EC-10014337174     18-64   M
# 4     EU-EC-10014337505     18-64   M
# ...                 ...       ...  ..
# 1679  EU-EC-10014351380     18-64   M
# 1680  EU-EC-10016516063     18-64   F
# 1681  EU-EC-10016508453     18-64   F
# 1682  EU-EC-10016392820     65-85   F
# 1683  EU-EC-10016320191     18-64   M
#
#                                           SYMPTOMS_LIST VAX_MANU
# 0                  [Myalgia, Pain, Peripheral swelling]  NOVAVAX
# 1                 [Fatigue, Headache, Tension headache]  NOVAVAX
# 2     [Herpes zoster, Muscular weakness, Neuralgia, ...  NOVAVAX
# 3                                       [Adverse event]  NOVAVAX
# 4     [Chest discomfort, Hypoaesthesia, Mobility dec...  NOVAVAX
# ...                                                 ...      ...
# 1679               [Pericardial effusion, Pericarditis]  NOVAVAX
# 1680  [Pain in extremity, Vaccination site erythema,...  NOVAVAX
# 1681  [Chills, Headache, Insomnia, Neuropathy periph...  NOVAVAX
# 1682  [Body temperature increased, Chest pain, Dizzi...  NOVAVAX
# 1683  [Cough, Decreased appetite, Feeling abnormal, ...  NOVAVAX
#
# [1684 rows x 5 columns]

# %%
data_EU_valneva = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Valneva' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_valneva = pd.concat([data_EU_valneva, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_valneva.head(2)
data_EU_valneva.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_valneva = data_EU_valneva[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_valneva.head(2)
data_EU_valneva["SYMPTOMS_LIST"] = data_EU_valneva["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_valneva
data_EU_valneva["AGE_GROUP"] = data_EU_valneva["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_valneva
data_EU_valneva["SEX"] = data_EU_valneva["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_valneva["SEX"] = data_EU_valneva["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_valneva["SEX"] = data_EU_valneva["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_valneva
data_EU_valneva['VAX_MANU'] = "VALNEVA"
data_EU_valneva
# Out:
# EU Files\EU Valneva 1 2022.csv
# EU Files\EU Valneva 1 2023.csv
#                 EU_ID      AGE_GROUP SEX  \
# 0   EU-EC-10014179682          18-64   F
# 1   EU-EC-10014166642          18-64   M
# 2   EU-EC-10014171307  Not Specified   F
# 3   EU-EC-10014161079          18-64   F
# 4   EU-EC-10014092652          65-85   F
# 5   EU-EC-10014037360  Not Specified   M
# 6   EU-EC-10013924383          65-85   M
# 7   EU-EC-10013806943          65-85   F
# 8   EU-EC-10013806979  Not Specified   M
# 9   EU-EC-10013807664          65-85   M
# 10  EU-EC-10013759111  Not Specified   F
# 11  EU-EC-10013745221  Not Specified   F
# 12  EU-EC-10013731463  Not Specified   F
# 13  EU-EC-10013731474  Not Specified   F
# 14  EU-EC-10013731520  Not Specified   F
# 15  EU-EC-10013732404  Not Specified   M
# 16  EU-EC-10013722409          18-64   F
# 17  EU-EC-10013702717          18-64   F
# 18  EU-EC-10013705045          18-64   M
# 19  EU-EC-10013596070          18-64   F
# 20  EU-EC-10013597930  Not Specified   F
# 21  EU-EC-10013496855          18-64   U
# 22  EU-EC-10013464027          65-85   M
# 23  EU-EC-10015999989          18-64   F
# 24  EU-EC-10015962229          18-64   M
# 25  EU-EC-10015386121          18-64   M
# 26  EU-EC-10015367783  Not Specified   M
# 27  EU-EC-10015264438          18-64   F
# 28  EU-EC-10015120337          18-64   M
# 29  EU-EC-10014908906          18-64   F
# 30  EU-EC-10014407259          18-64   F
# 31  EU-EC-10014367972          18-64   M
# 32  EU-EC-10014367980          12-17   M
# 33  EU-EC-10014349165  Not Specified   F
#
#                                         SYMPTOMS_LIST VAX_MANU
# 0           [Headache, Off label use, Taste disorder]  VALNEVA
# 1    [Anaphylactic reaction, Dyspnoea, Off label use]  VALNEVA
# 2    [Interchange of vaccine products, Off label use]  VALNEVA
# 3                          [Headache, Taste disorder]  VALNEVA
# 4                 [Limb immobilisation, Paraesthesia]  VALNEVA
# 5   [Interchange of vaccine products, No adverse e...  VALNEVA
# 6            [Off label use, Vaccination site warmth]  VALNEVA
# 7   [Interchange of vaccine products, Off label us...  VALNEVA
# 8    [Interchange of vaccine products, Off label use]  VALNEVA
# 9   [Body temperature increased, Interchange of va...  VALNEVA
# 10  [Interchange of vaccine products, No adverse e...  VALNEVA
# 11  [Interchange of vaccine products, No adverse e...  VALNEVA
# 12  [Interchange of vaccine products, No adverse e...  VALNEVA
# 13  [Interchange of vaccine products, No adverse e...  VALNEVA
# 14  [Interchange of vaccine products, No adverse e...  VALNEVA
# 15  [Exposure to SARS-CoV-2, Interchange of vaccin...  VALNEVA
# 16  [Expired product administered, Interchange of ...  VALNEVA
# 17                                    [Off label use]  VALNEVA
# 18  [Incomplete course of vaccination, Product ava...  VALNEVA
# 19                  [No adverse event, Off label use]  VALNEVA
# 20    [Accidental exposure to product, Off label use]  VALNEVA
# 21             [Off label use, Vaccination site pain]  VALNEVA
# 22            [Headache, Influenza, Weight increased]  VALNEVA
# 23                            [Androgenetic alopecia]  VALNEVA
# 24  [Dyspnoea exertional, Fatigue, Pain, Palpitati...  VALNEVA
# 25  [Arthralgia, Pain in extremity, Tension headache]  VALNEVA
# 26  [Incomplete course of vaccination, Influenza, ...  VALNEVA
# 27                                        [Urticaria]  VALNEVA
# 28                  [Eye haematoma, Facial paralysis]  VALNEVA
# 29          [Alopecia, Dyspnoea, Fatigue, Somnolence]  VALNEVA
# 30                                    [Hyperhidrosis]  VALNEVA
# 31                        [Vaccination site reaction]  VALNEVA
# 32                        [Vaccination site reaction]  VALNEVA
# 33                                         [Alopecia]  VALNEVA

# %%
data_EU_vidprevtyn = pd.DataFrame()
for file_name in glob.glob('EU Files/EU Vidprevtyn' + '*.csv'):
    x = pd.read_csv(file_name, low_memory = False)
    data_EU_vidprevtyn = pd.concat([data_EU_vidprevtyn, x], axis = 0, ignore_index = True)
    print(file_name)
# data_EU_vidprevtyn.head(2)
data_EU_vidprevtyn.columns = ["EU_ID", "1", "2", "3", "4", "5", "AGE_GROUP", "6", "7", "SEX", "SYMPTOMS_LIST", "8", "9", "10"]
data_EU_vidprevtyn = data_EU_vidprevtyn[["EU_ID", "AGE_GROUP", "SEX", "SYMPTOMS_LIST"]]
# data_EU_vidprevtyn.head(2)
data_EU_vidprevtyn["SYMPTOMS_LIST"] = data_EU_vidprevtyn["SYMPTOMS_LIST"].apply(extract_symptoms)
# data_EU_vidprevtyn
data_EU_vidprevtyn["AGE_GROUP"] = data_EU_vidprevtyn["AGE_GROUP"].astype(str).str.replace("Years", "").str.strip()
# data_EU_vidprevtyn
data_EU_vidprevtyn["SEX"] = data_EU_vidprevtyn["SEX"].astype(str).str.replace("emale", "").str.strip()
data_EU_vidprevtyn["SEX"] = data_EU_vidprevtyn["SEX"].astype(str).str.replace("ale", "").str.strip()
data_EU_vidprevtyn["SEX"] = data_EU_vidprevtyn["SEX"].astype(str).str.replace("Not Specified", "U").str.strip()
# data_EU_vidprevtyn
data_EU_vidprevtyn['VAX_MANU'] = "VIDPREVTYN"
data_EU_vidprevtyn
# Out:
# EU Files\EU Vidprevtyn 1 2023.csv
#                  EU_ID      AGE_GROUP SEX  \
# 0    EU-EC-10016550757          18-64   F
# 1    EU-EC-10016535561          18-64   F
# 2    EU-EC-10016488047  Not Specified   F
# 3    EU-EC-10016442411          65-85   F
# 4    EU-EC-10016443315          65-85   F
# ..                 ...            ...  ..
# 411  EU-EC-10015031220          18-64   F
# 412  EU-EC-10014987895          18-64   M
# 413  EU-EC-10014940221          65-85   U
# 414  EU-EC-10014652497          18-64   M
# 415  EU-EC-10014605397          18-64   F
#
#                                          SYMPTOMS_LIST    VAX_MANU
# 0                         [Fatigue, Pain in extremity]  VIDPREVTYN
# 1    [Asthenia, Cyanosis, Diarrhoea, Fatigue, Heada...  VIDPREVTYN
# 2                                          [Dizziness]  VIDPREVTYN
# 3                                [Peripheral swelling]  VIDPREVTYN
# 4                                          [Dizziness]  VIDPREVTYN
# ..                                                 ...         ...
# 411  [Asthenia, Musculoskeletal stiffness, Myalgia,...  VIDPREVTYN
# 412                  [Eye pruritus, Ocular discomfort]  VIDPREVTYN
# 413  [Feeling cold, Influenza like illness, Pain in...  VIDPREVTYN
# 414  [Gastrointestinal disorder, Immunisation react...  VIDPREVTYN
# 415                            [Immunisation reaction]  VIDPREVTYN
#
# [416 rows x 5 columns]

# %%
data_EU_full = pd.concat([data_EU_astrazeneca, data_EU_janssen, data_EU_moderna, data_EU_novavax, data_EU_pfizer, data_EU_valneva, data_EU_vidprevtyn], axis = 0, ignore_index = True)
data_EU_full
# Out:
#                      EU_ID AGE_GROUP SEX  \
# 0        EU-EC-10011128636     18-64   M
# 1        EU-EC-10011128637     65-85   F
# 2        EU-EC-10011128695     18-64   M
# 3        EU-EC-10011128705     65-85   F
# 4        EU-EC-10011128724     65-85   M
# ...                    ...       ...  ..
# 1498250  EU-EC-10015031220     18-64   F
# 1498251  EU-EC-10014987895     18-64   M
# 1498252  EU-EC-10014940221     65-85   U
# 1498253  EU-EC-10014652497     18-64   M
# 1498254  EU-EC-10014605397     18-64   F
#
#                                              SYMPTOMS_LIST     VAX_MANU
# 0        [Dysaesthesia, Muscle contractions involuntary...  ASTRAZENECA
# 1        [Abdominal pain upper, Blood pressure increase...  ASTRAZENECA
# 2                                               [Tinnitus]  ASTRAZENECA
# 3                                              [Urticaria]  ASTRAZENECA
# 4                                        [Cardiac failure]  ASTRAZENECA
# ...                                                    ...          ...
# 1498250  [Asthenia, Musculoskeletal stiffness, Myalgia,...   VIDPREVTYN
# 1498251                  [Eye pruritus, Ocular discomfort]   VIDPREVTYN
# 1498252  [Feeling cold, Influenza like illness, Pain in...   VIDPREVTYN
# 1498253  [Gastrointestinal disorder, Immunisation react...   VIDPREVTYN
# 1498254                            [Immunisation reaction]   VIDPREVTYN
#
# [1498255 rows x 5 columns]

# %%
# data_EU_full.to_csv("Final Files/EU Full Data.csv", index = False)
